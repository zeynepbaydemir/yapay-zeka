# %%
import warnings
warnings.filterwarnings('ignore')

from wordcloud import WordCloud, STOPWORDS
import os

import pandas as pd
import numpy as np
import scipy as sp
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB

from sklearn.linear_model import LogisticRegression

from sklearn import metrics

from textblob import TextBlob, Word

from nltk.stem.snowball import SnowballStemmer
import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

from PIL import Image

import nltk
from langdetect import detect
from wordcloud import WordCloud

# %%
ali = pd.read_csv('ali.csv')
ali.head()
# Out:
#                                           Unnamed: 0
# 0                                                NaN
# 1  I have a hoarding problem, which I’m hoping is...
# 2  The last time I was at home in San Francisco, ...
# 3  But I think that for marriage, it can be nice ...
# 4  My last boyfriend was Cuban and his family wou...

# %%
ali = ali.dropna()

# %%
#altyazi = altyazi.loc[:, ~altyazi.columns.str.contains('^Unnamed')] -> tüm veri setimi berbat etti bu kod

# %%
ali.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 1 to 10
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8 non-null      object
# dtypes: object(1)
# memory usage: 128.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc1.png')
    print('Word cloud Saved Successfully')
    path = 'wc1.png'
    display(Image.open(path))

# %%
text1 = ali

# %%
create_wordcloud(text1)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
anthony = pd.read_csv('anthony.csv')
anthony.head()
# Out:
#                                           Unnamed: 0
# 0                                                NaN
# 1  My dad was a hard-ass. One of those guys who b...
# 2  As a kid, my dad’s prized possession, my dad’s...
# 3  I mean it, my dad was no joke. My dad did not ...
# 4  When I was a kid, I used to fantasize about ge...

# %%
anthony = anthony.dropna()

# %%
anthony.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 1 to 6
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      object
# dtypes: object(1)
# memory usage: 80.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc.png')
    print('Word cloud Saved Successfully')
    path = 'wc.png'
    display(Image.open(path))

# %%
text2 = anthony

# %%
create_wordcloud(text2)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
bill = pd.read_csv('bill.csv')
bill.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
bill = bill.dropna()

# %%
bill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      object
# dtypes: object(1)
# memory usage: 124.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc2.png')
    print('Word cloud Saved Successfully')
    path = 'wc2.png'
    display(Image.open(path))

# %%
text3 = bill

# %%
create_wordcloud(text3)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
bo = pd.read_csv('bo.csv')
bo.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
bo = bo.dropna()

# %%
bo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      object
# dtypes: object(1)
# memory usage: 124.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc3.png')
    print('Word cloud Saved Successfully')
    path = 'wc3.png'
    display(Image.open(path))

# %%
text4 = bo

# %%
create_wordcloud(text4)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
dave = pd.read_csv('dave.csv')
dave.head()
# Out:
#                                           Unnamed: 0
# 0  I don’t know if you ever saw on TMZ the big he...
# 1  This went on for a long time. And then, after ...
# 2                                                NaN
# 3                                                NaN
# 4  Uh… So, the reason a lot of people haven’t hea...

# %%
dave = dave.dropna()

# %%
dave.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 21
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     object
# dtypes: object(1)
# memory usage: 256.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc4.png')
    print('Word cloud Saved Successfully')
    path = 'wc4.png'
    display(Image.open(path))

# %%
text5 = dave

# %%
create_wordcloud(text5)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
hasan = pd.read_csv('hasan.csv')
hasan.head()
# Out:
#                                           Unnamed: 0
# 0  And I think it’s just that, like, immigrants l...
# 1  So my dad marries my mom, they come to the Sta...
# 2  Roll call was a problem. It was a big deal for...
# 3  I still can’t understand some of you. There ar...
# 4  I remember being in the grocery store. And we’...

# %%
hasan = hasan.dropna()

# %%
hasan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 9
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8 non-null      object
# dtypes: object(1)
# memory usage: 128.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc5.png')
    print('Word cloud Saved Successfully')
    path = 'wc5.png'
    display(Image.open(path))

# %%
text6 = hasan

# %%
create_wordcloud(text6)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
jim = pd.read_csv('jim.csv')
jim.head()
# Out:
#                                  Unnamed: 0
# 0      ♪ From time to time We all get sad ♪
# 1  ♪ One day you’re happy Then you’re sad ♪
# 2                       ♪ And then, uh-oh ♪
# 3                                       NaN

# %%
jim = jim.dropna()

# %%
jim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4 non-null      object
# dtypes: object(1)
# memory usage: 64.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc6.png')
    print('Word cloud Saved Successfully')
    path = 'wc6.png'
    display(Image.open(path))

# %%
text7 = jim

# %%
create_wordcloud(text7)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
joe = pd.read_csv('joe.csv')
joe.head()
# Out:
#                                           Unnamed: 0
# 0                                                XG
#
# 1                                                NaN
# 2  Some cults aren’t that good. They get fucking ...
# 3                                                NaN

# %%
joe = joe.dropna()

# %%
joe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2 non-null      object
# dtypes: object(1)
# memory usage: 32.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc7.png')
    print('Word cloud Saved Successfully')
    path = 'wc7.png'
    display(Image.open(path))

# %%
text8 = joe

# %%
create_wordcloud(text8)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
john = pd.read_csv('john.csv')
john.head()
# Out:
#                                           Unnamed: 0
# 0                                                NaN
# 1                                                NaN
# 2  I didn’t mean to make it sound like we don’t w...
# 3                                                X=
#
# 4                                                NaN

# %%
john = john.dropna()

# %%
john.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 2 to 9
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6 non-null      object
# dtypes: object(1)
# memory usage: 96.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc8.png')
    print('Word cloud Saved Successfully')
    path = 'wc8.png'
    display(Image.open(path))

# %%
text9 = john

# %%
create_wordcloud(text9)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
louis = pd.read_csv('louis.csv')
louis.head()
# Out:
#                                           Unnamed: 0
# 0                                                NaN
# 1                                                NaN
# 2  You ever flush a pet down the toilet? I had to...
# 3                                   “The Food Chain”
# 4  Must be awful to be other kinds of stuff, You ...

# %%
louis = louis.dropna()

# %%
louis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 2 to 21
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     object
# dtypes: object(1)
# memory usage: 256.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc9.png')
    print('Word cloud Saved Successfully')
    path = 'wc9.png'
    display(Image.open(path))

# %%
text10 = louis

# %%
create_wordcloud(text10)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
mike = pd.read_csv('mike.csv')
mike.head()
# Out:
#                                           Unnamed: 0
# 0  And I said, “Well, first of all, it just seems...
# 1  Second of all, monogamy’s impossible, or at th...
# 2                                                NaN
# 3                                                NaN
# 4  I sit down with Lisa on the scrambler, and I’m...

# %%
mike = mike.dropna()

# %%
mike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 15
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11 non-null     object
# dtypes: object(1)
# memory usage: 176.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc10.png')
    print('Word cloud Saved Successfully')
    path = 'wc10.png'
    display(Image.open(path))

# %%
text11 = mike

# %%
create_wordcloud(text11)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>

# %%
ricky = pd.read_csv('ricky.csv')
ricky.head()
# Out:
#                                           Unnamed: 0
# 0                                                NaN
# 1  I could do without the safety video. That’s al...
# 2                                                NaN
# 3                                                NaN
# 4  But… But the world is getting worse. And I bla...

# %%
ricky = ricky.dropna()

# %%
ricky.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 1 to 4
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2 non-null      object
# dtypes: object(1)
# memory usage: 32.0+ bytes

# %%
def create_wordcloud(text):
    mask = np.array(Image.open('cloud.png'))
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color='white',
                  mask = mask,
                  max_words=25000,
                  stopwords=stopwords)
    wc.generate(str(text))
    wc.to_file('wc11.png')
    print('Word cloud Saved Successfully')
    path = 'wc11.png'
    display(Image.open(path))

# %%
text12 = ricky

# %%
create_wordcloud(text12)
# Out:
# Word cloud Saved Successfully
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1334x945>
