# %% [markdown]
# ### Web Scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url='https://www.resmigazete.gov.tr/'
response = requests.get(url, headers = {'User-agent': 'your bot 0.1'})

# %%
response.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="tr">\r\n\r\n<head>\r\n    <meta charset="UTF-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=yes">\r\n\r\n    <meta http-equiv="X-UA-Compatible" content="ie=edge">\r\n    <title>T.C. Resmî Gazete</title>\r\n\r\n    <link href="/assets/vendors/rubikfonts/rubik.css" rel="stylesheet">\r\n\r\n    <link href="/assets/src/css/bootstrap.min.css" rel="stylesheet">\r\n    <link href="/assets/vendors/fontawesome/css/all.min.css" rel="stylesheet">\r\n    <link href="/assets/vendors/fontawesome/css/v4-shims.min.css" rel="stylesheet">\r\n\r\n    <link href="/assets/src/css/tempusdominus-bootstrap-4.min.css" rel="stylesheet">\r\n\r\n    <link href="/assets/vendors/datatables/dataTables.bootstrap4.min.css" rel="stylesheet">\r\n    <link href="/assets/vendors/datatables/Responsive-2.2.2/css/responsive.bootstrap4.min.css" rel="stylesheet">\r\n    <link href="/assets/vendors/datatables/Scroller-1.5.0/css/scroller.bootstrap4.m
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.beautify

# %%
continer = soup.findAll('div',{'class':'showcase row'})

# %%
mevzuatTur = soup.findAll('div', {'class':'form-group col-12'})
basliklar = soup.findAll('div', {'class':'fihrist-item mb-1'})
tarih = soup.findAll('span', {'id':'spanGazeteTarih'})


print(mevzuat_tur)
print(basliklar)
print(yil)
# Out:
# [<div class="form-group col-12">
# <label for="genelaranacakkelime" title="Aranacak Kelime">Aranacak Kelime</label>
# <input class="form-control form-control-sm" id="genelaranacakkelime" name="genelaranacakkelime" title="Aranacak Kelime" type="text"/>
# </div>, <div class="form-group col-12">
# <label for="formGroupExampleInput2" title="Resmî Gazete Sayısı">Resmî Gazete Sayısı</label>
# <input class="form-control form-control-sm" id="formGroupExampleInput2" min="1" name="genelsayi" placeholder="" title="Resmî Gazete Sayısı" type="number"/>
# </div>, <div class="form-group col-12">
# <label for="selectGenelMevzuatTuru" title="Mevzuat Türü">Mevzuat Türü</label>
# <select class="form-control form-control-sm select2-autocomplete" id="selectGenelMevzuatTuru" name="genelmevzuatturu" style="width:100%;">
# <option selected="" value="">Tamamı</option>
# <option value="0010.02">ANAYASA</option>
# <option value="0010">KANUNLAR</option>
# ...

# %%
m = []
b = []
t = []

columns = ['mevzuatTur', 'basliklar', 'tarih']
for(m1, b1, t1) in zip(mevzuatTur, basliklar, tarih):
    m.append(m1.text)
    b.append(b1.text)
    t.append(t1.text)

# %%
d = {'mevzuatTur':m , 'basliklar':b, 'tarih':t}
pd.DataFrame(d)
# Out:
#               mevzuatTur                                          basliklar  \
# 0  \nAranacak Kelime\n\n  –– Dokuz Eylül Üniversitesi Ege Bölgesi Uygula...
#
#                                                tarih
# 0  11 Aralık 2023 Tarihli ve 32396 Sayılı Resmî G...

# %%
# Her bir elementin metin içeriğini al
mevzuatTur_text = [element.text.strip() for element in mevzuatTur]
basliklar_text = [element.text.strip() for element in basliklar]
tarih_text = [element.text.strip() for element in tarih]

# Elde ettiğiniz text içeriklerini bir dosyaya yazın
with open('ResmiGazete.txt', 'w', encoding='utf-8') as file:
    file.write("Mevzuat Tür:\n")
    for item in mevzuatTur_text:
        file.write("%s\n" % item)

    file.write("\nBaşlıklar:\n")
    for item in basliklar_text:
        file.write("%s\n" % item)

    file.write("\nTarih:\n")
    for item in tarih_text:
        file.write("%s\n" % item)
